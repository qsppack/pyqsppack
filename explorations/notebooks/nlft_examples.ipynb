# %% [markdown]
# # NLFT Examples

# %% [markdown]
# This notebook goes through all of the examples and demonstrates that even if our constraints are violated (by not oversampling or rescaling our target functions), the NLFT method with Weiss still results in an accurate function.

# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/jameslarsen/Desktop/LBL/qsppack
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from qsppack==0.3.12) (2.3.2)
# Requirement already satisfied: scipy in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from qsppack==0.3.12) (1.16.1)
# Requirement already satisfied: matplotlib in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from qsppack==0.3.12) (3.10.3)
# Requirement already satisfied: cvxpy in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from qsppack==0.3.12) (1.7.1)
# Requirement already satisfied: sympy in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from qsppack==0.3.12) (1.14.0)
# Requirement already satisfied: osqp>=0.6.2 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from cvxpy->qsppack==0.3.12) (1.0.4)
# Requirement already satisfied: clarabel>=0.5.0 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from cvxpy->qsppack==0.3.12) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from cvxpy->qsppack==0.3.12) (3.2.7.post2)
# Requirement already satisfied: cffi in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from clarabel>=0.5.0->cvxpy->qsppack==0.3.12) (1.17.1)
# Requirement already satisfied: jinja2 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from osqp>=0.6.2->cvxpy->qsppack==0.3.12) (3.1.6)
# Requirement already satisfied: setuptools in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from osqp>=0.6.2->cvxpy->qsppack==0.3.12) (80.9.0)
# Requirement already satisfied: joblib in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from osqp>=0.6.2->cvxpy->qsppack==0.3.12) (1.5.1)
# Requirement already satisfied: pycparser in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from cffi->clarabel>=0.5.0->cvxpy->qsppack==0.3.12) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from jinja2->osqp>=0.6.2->cvxpy->qsppack==0.3.12) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from matplotlib->qsppack==0.3.12) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from matplotlib->qsppack==0.3.12) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from matplotlib->qsppack==0.3.12) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from matplotlib->qsppack==0.3.12) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from matplotlib->qsppack==0.3.12) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from matplotlib->qsppack==0.3.12) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from matplotlib->qsppack==0.3.12) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from matplotlib->qsppack==0.3.12) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->qsppack==0.3.12) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages (from sympy->qsppack==0.3.12) (1.3.0)
# Building wheels for collected packages: qsppack
#   Building editable for qsppack (pyproject.toml) ... done
#   Created wheel for qsppack: filename=qsppack-0.3.12-0.editable-py3-none-any.whl size=3446 sha256=b216bdaa468ef49db69862ddffb2e1fd28861f707d73379fd67a61a89a9ab49d
#   Stored in directory: /private/var/folders/bz/68lg1ys109jbpl3rbpx1jjmw0000gn/T/pip-ephem-wheel-cache-lgpi_xdc/wheels/80/31/61/69b6e2fff14a2137693432a0f7592930269847699f6173530f
# Successfully built qsppack
# Installing collected packages: qsppack
#   Attempting uninstall: qsppack
#     Found existing installation: qsppack 0.3.12
#     Uninstalling qsppack-0.3.12:
#       Successfully uninstalled qsppack-0.3.12
# Successfully installed qsppack-0.3.12

# %%
import numpy as np
from qsppack.utils import cvx_poly_coef
from qsppack.solver import solve
from qsppack.utils import chebyshev_to_func, get_entry
import matplotlib.pyplot as plt

# %% [markdown]
# Outline:
# 1. *Linear System Problem                (works like a charm)
# 2. *Negative Power Functions             (works like a charm)
# 3. Hamiltonian Simulation               (constraints not violated)
# 4. Quantum Gaussian Filter              (constraints not violated)
# 5. *Singular Value Threshold Projector   (works like a charm)            (MIGHT BE WORST EXAMPLE)
# 6. Singular Vector Transformation       (constraints not violated)
# 7. *Uniform Singular Value Amplification (works like a charm)            (MIGHT BE BEST EXAMPLE)
# 8. *Gaussian State                       (works like a charm)
# 9. Kaiser Window State                  (constraints not violated)
# 10. Gibbs State                         (constraints not violated)

# %% [markdown]
# ## Linear Systems Problem

# %%
kappa = 10
targ = lambda x: 1/(kappa*x)
deg = 71
parity = deg % 2
opts = {
    'intervals': [1/kappa, 1],
    'objnorm': np.inf,
    'epsil': 0.01,
    'npts': 71,
    'fscale': 1,
    'isplot': False,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)

# plt.plot(xlist, QSP_value - func_value)
# plt.xlabel('$x$', fontsize=12)
# plt.ylabel('$g(x,\\Phi^*)-f_\\mathrm{poly}(x)$', fontsize=12)
# plt.show()
# Out:
# norm error = 0.010000000005610632
# max of solution = 0.9899999999943894
# /var/folders/bz/68lg1ys109jbpl3rbpx1jjmw0000gn/T/ipykernel_50775/2400647397.py:2: RuntimeWarning: divide by zero encountered in divide
#   targ = lambda x: 1/(kappa*x)
# The residual error is
# 0.024624629226102424

# %%
plt.plot(xlist, targ(xlist), label='True')
plt.plot(xlist, func_value, label='Polynomial Approximation')
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, np.ones(len(xlist)), "k--", label='Constraint')
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.ylim([0, 1.1])
plt.xlim([0, 1])
plt.show()
# Out:
# /var/folders/bz/68lg1ys109jbpl3rbpx1jjmw0000gn/T/ipykernel_50775/2400647397.py:2: RuntimeWarning: divide by zero encountered in divide
#   targ = lambda x: 1/(kappa*x)

# %%
kappa = 10
targ = lambda x: 1/(kappa*x)
deg = 71
parity = deg % 2
opts = {
    'intervals': [1/kappa, 1],
    'objnorm': np.inf,
    'epsil': 0.01,
    'npts': 71,
    'fscale': 1,
    'isplot': False,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)

plt.plot(xlist, targ(xlist), label='True')
plt.plot(xlist, func_value, label='Polynomial Approximation')
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, QSP_value_new, label='QSP_new')
plt.plot(xlist, np.ones(len(xlist)), "k--", label='Constraint')
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.ylim([-0.1, 1.1])
plt.xlim([0, 1])
plt.show()
# Out:
# norm error = 0.010000000005610632
# max of solution = 0.9899999999943894
# using OG Weiss
# /var/folders/bz/68lg1ys109jbpl3rbpx1jjmw0000gn/T/ipykernel_72776/3676625706.py:2: RuntimeWarning: divide by zero encountered in divide
#   targ = lambda x: 1/(kappa*x)
# The residual error is
# 0.024624629226102424

# %%
np.savez("nlft_test.npz", value=QSP_value_new)

# %%
max(QSP_value)
# Out:
# np.float64(0.9998298562206887)

# %%
max(QSP_value_new)
# Out:
# np.float64(0.9998098158257605)

# %%
QSP_value_new - QSP_value
# Out:
# array([ 0.00000000e+00,  1.58903338e-04,  3.17502647e-04,  4.75494648e-04,
#         6.32577562e-04,  7.88451857e-04,  9.42820982e-04,  1.09539210e-03,
#         1.24587682e-03,  1.39399188e-03,  1.53945986e-03,  1.68200987e-03,
#         1.82137819e-03,  1.95730892e-03,  2.08955460e-03,  2.21787682e-03,
#         2.34204677e-03,  2.46184582e-03,  2.57706599e-03,  2.68751052e-03,
#         2.79299423e-03,  2.89334403e-03,  2.98839930e-03,  3.07801222e-03,
#         3.16204814e-03,  3.24038585e-03,  3.31291784e-03,  3.37955053e-03,
#         3.44020444e-03,  3.49481435e-03,  3.54332941e-03,  3.58571317e-03,
#         3.62194367e-03,  3.65201339e-03,  3.67592919e-03,  3.69371229e-03,
#         3.70539808e-03,  3.71103599e-03,  3.71068928e-03,  3.70443483e-03,
#         3.69236284e-03,  3.67457653e-03,  3.65119183e-03,  3.62233696e-03,
#         3.58815208e-03,  3.54878880e-03,  3.50440976e-03,  3.45518812e-03,
#         3.40130703e-03,  3.34295910e-03,  3.28034586e-03,  3.21367710e-03,
#         3.14317032e-03,  3.06905009e-03,  2.99154739e-03,  2.91089897e-03,
#         2.82734666e-03,  2.74113671e-03,  2.65251906e-03,  2.56174670e-03,
#         2.46907492e-03,  2.37476062e-03,  2.27906160e-03,  2.18223587e-03,
#         2.08454093e-03,  1.98623307e-03,  1.88756671e-03,  1.78879371e-03,
#         1.69016266e-03,  1.59191830e-03,  1.49430081e-03,  1.39754524e-03,
#         1.30188088e-03,  1.20753065e-03,  1.11471061e-03,  1.02362936e-03,
#         9.34487540e-04,  8.47477362e-04,  7.62782132e-04,  6.80575833e-04,
#         6.01022715e-04,  5.24276935e-04,  4.50482219e-04,  3.79771557e-04,
#         3.12266938e-04,  2.48079113e-04,  1.87307399e-04,  1.30039514e-04,
#         7.63514489e-05,  2.63073784e-05, -2.00403949e-05, -6.26514594e-05,
#        -1.01497277e-04, -1.36561128e-04, -1.67838027e-04, -1.95334592e-04,
#        -2.19068892e-04, -2.39070253e-04, -2.55379030e-04, -2.68046352e-04,
#        -2.77133835e-04, -2.82713258e-04, -2.84866219e-04, -2.83683760e-04,
#         2.90799858e-05,  2.95380675e-05,  2.76812803e-05,  2.35606269e-05,
#         1.74155235e-05,  9.67410892e-06,  9.37256727e-07, -8.05527768e-06,
#        -1.64768499e-05, -2.34826633e-05, -2.82918523e-05, -3.02772783e-05,
#        -2.90550854e-05, -2.45638953e-05, -1.71218134e-05, -7.44855474e-06,
#         3.35954631e-06,  1.39116008e-05,  2.26666265e-05,  2.81382793e-05,
#         2.91471855e-05,  2.50946260e-05,  1.62153874e-05,  3.75089163e-06,
#        -1.00307083e-05, -2.20478282e-05, -2.89241310e-05, -2.78486262e-05,
#        -1.77319948e-05, -4.62129802e-07,  1.81958311e-05,  2.89219145e-05,
#         2.18857073e-05, -5.04631832e-06, -2.91321410e-05,  2.91520145e-05])

# %%
# Load QSP_value_new from the saved .npz file
data = np.load("nlft_test.npz")
QSP_value_new = data['value']

# Calculate the difference between QSP_value_new and QSP_value
difference = QSP_value_new - QSP_value

# Plot the difference
plt.plot(xlist, difference, label='Difference (QSP_value_new - QSP_value)')
plt.xlabel('$x$', fontsize=12)
plt.ylabel('Difference', fontsize=12)
plt.title('Difference between QSP_value_new and QSP_value')
plt.grid()
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Negative Power Functions

# %%
kappa = 10
targ = lambda x: 1/(x**2)
deg = 70
parity = deg % 2

opts = {
    'intervals': [1/kappa, 1],
    'objnorm': np.inf,
    'epsil': 0.01,
    'npts': 70,
    'fscale': 1/(kappa**2),
    'isplot': False,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)
# Out:
# norm error = 0.019861397887987464
# max of solution = 0.9899999992053649
# using OG Weiss
# /var/folders/bz/68lg1ys109jbpl3rbpx1jjmw0000gn/T/ipykernel_72776/2730026234.py:2: RuntimeWarning: divide by zero encountered in divide
#   targ = lambda x: 1/(x**2)
# The residual error is
# 0.08321406958829414

# %%
plt.plot(xlist, targ(xlist)*opts['fscale'], label='True')
plt.plot(xlist, func_value, label='Polynomial Approximation')
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, np.ones(len(xlist)), "k--", label='Constraint')
plt.plot(xlist, -np.ones(len(xlist)), "k--")
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.ylim([-1.1, 1.1])
plt.xlim([0, 1])
plt.show()
# Out:
# /var/folders/bz/68lg1ys109jbpl3rbpx1jjmw0000gn/T/ipykernel_72776/2730026234.py:2: RuntimeWarning: divide by zero encountered in divide
#   targ = lambda x: 1/(x**2)

# %%
plt.plot(xlist, QSP_value-func_value)
plt.yscale("log")
plt.xlim([0, 1])
plt.show()

# %% [markdown]
# ## Hamiltonian Simulation

# %% [markdown]
# This example is not very interesting since it doesn't violate our constraint.

# %%
tau = 10
targ = lambda x: np.cos(tau*x)
deg = 150
parity = deg % 2

opts = {
    'intervals': [0, 1],
    'objnorm': np.inf,
    'epsil': 0.01,
    'npts': 150,
    'fscale': 1,
    'isplot': False,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)
# Out:
# norm error = 0.010000000013508314
# max of solution = 0.9899999999864917
# The residual error is
# 1.0608436351589035e-10

# %%
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, func_value, label='True')
plt.plot(xlist, np.ones(len(xlist)), "k--")
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Quantum Gaussian Filter

# %% [markdown]
# This example is not very interesting since it doesn't violate our constraint.

# %%
targ = lambda x: np.exp(-(np.abs(x) - 0.5)**2 / 0.1**2)
deg = 70
parity = deg % 2

opts = {
    'intervals': [0, 1],
    'objnorm': np.inf,
    'epsil': 0.01,
    'npts': 70,
    'fscale': 1,
    'isplot': False,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)
# Out:
# norm error = 0.005770689376769722
# max of solution = 0.9899999999690915
# The residual error is
# 6.077068531729068e-07

# %%
plt.plot(xlist, targ(xlist)*opts['fscale'], label='True')
plt.plot(xlist, func_value, label='Polynomial Approximation')
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, np.ones(len(xlist)), "k--", label='Constraint')
plt.plot(xlist, -np.ones(len(xlist)), "k--")
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.ylim([-0.1, 1.1])
plt.xlim([0, 1])
plt.show()

# %% [markdown]
# ## Singular Value Threshold Projector

# %% [markdown]
# Something weird is going on with my convex optimization routine for this one... Definitely warrants more thought.

# %%
delta = 0.05
targ = np.vectorize(lambda x: 1 if np.abs(x) < 0.5 else 0)
deg = 100
parity = deg % 2

opts = {
    'intervals': [0, 0.5-delta, 0.5+delta, 1],
    'objnorm': np.inf,
    'epsil': 0,
    'npts': 100,
    'fscale': 0.999,
    'maxiter': 100,
    'isplot': False,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)
# Out:
# norm error = 0.0003385988504919224
# max of solution = 0.9993385987991814
# using OG Weiss
# The residual error is
# 0.0013775172562154603

# %%
plt.plot(xlist, targ(xlist)*opts['fscale'], label='True')
plt.plot(xlist, func_value, label='Polynomial Approximation')
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, np.ones(len(xlist)), "k--", label='Constraint')
plt.plot(xlist, -np.ones(len(xlist)), "k--")
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.ylim([-0.1, 1.1])
plt.xlim([0, 1])
plt.show()

# %%
max(func_value)
# Out:
# np.float64(1.0003756440659133)

# %%
max(QSP_value)
# Out:
# np.float64(0.9999849099693439)

# %%
plt.plot(xlist, QSP_value-func_value)
plt.yscale("log")
plt.xlim([0, 1])
plt.show()

# %% [markdown]
# ## Singular Vector Transformation

# %%
delta = 0.1
targ = lambda x: np.sign(x)
deg = 251
parity = deg % 2

opts = {
    'intervals': [delta, 1],
    'objnorm': np.inf,
    'epsil': 0,
    'npts': 251,
    'isplot': False,
    'fscale': 1,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)
# Out:
# /Users/jameslarsen/miniconda3/envs/qspy/lib/python3.13/site-packages/cvxpy/problems/problem.py:1539: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# norm error = 7.301126259129376e-09
# max of solution = 0.999999997972234
# The residual error is
# 1.8077426156448695e-05

# %%
plt.plot(xlist, targ(xlist)*opts['fscale'], label='True')
plt.plot(xlist, func_value, label='Polynomial Approximation')
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, np.ones(len(xlist)), "k--", label='Constraint')
plt.plot(xlist, -np.ones(len(xlist)), "k--")
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.ylim([-0.5, 1.1])
plt.xlim([0, 1])
plt.show()

# %%
plt.plot(xlist, QSP_value-func_value)
plt.yscale("log")
plt.xlim([0, 1])
plt.show()

# %% [markdown]
# ## Uniform Singular Value Amplification

# %%
a = 0.2
targ = lambda x: x / a
deg = 101
parity = deg % 2

opts = {
    'intervals': [0, a],
    'objnorm': np.inf,
    'epsil': 0,
    'npts': 101,
    'isplot': False,
    'fscale': 1,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)
# Out:
# norm error = 0.0013526970109043468
# max of solution = 0.9999999997341179
# The residual error is
# 0.35807144630707755

# %%
plt.plot(xlist, targ(xlist)*opts['fscale'], label='True')
plt.plot(xlist, func_value, label='Polynomial Approximation')
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, np.ones(len(xlist)), "k--", label='Constraint')
plt.plot(xlist, -np.ones(len(xlist)), "k--")
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.ylim([-1.1, 1.1])
plt.xlim([0, 1])
plt.show()

# %%
plt.plot(xlist, QSP_value-func_value)
plt.yscale("log")
plt.xlim([0, 1])
plt.show()

# %% [markdown]
# ## Gaussian State

# %%
beta = 100
targ = lambda x: np.exp(-beta/2 * np.arcsin(x)**2)
deg = 100
parity = deg % 2

opts = {
    'intervals': [0, np.sin(1)],
    'objnorm': np.inf,
    'epsil': 0,
    'npts': 100,
    'isplot': False,
    'fscale': 1,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)
# Out:
# norm error = 2.130348897289025e-09
# max of solution = 0.999999998939921
# The residual error is
# 0.013698780894815243

# %%
plt.plot(xlist, targ(xlist)*opts['fscale'], label='True')
plt.plot(xlist, func_value, label='Polynomial Approximation')
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, np.ones(len(xlist)), "k--", label='Constraint')
plt.plot(xlist, -np.ones(len(xlist)), "k--")
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.ylim([-0.01, 1.1])
plt.xlim([0, 1])
plt.show()

# %% [markdown]
# ## Kaiser Window State

# %%
from scipy.special import jv

# %%
beta = 8
targ = lambda x: jv(0, 1j*beta * np.sqrt(np.complex128(1 - 2*np.arcsin(x)**2))) / jv(0, 1j*beta)
targ = np.vectorize(targ)
deg = 100
parity = deg % 2

opts = {
    'intervals': [0, np.sin(1)],
    'objnorm': np.inf,
    'epsil': 0,
    'npts': 100,
    'isplot': False,
    'fscale': 1,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)
# Out:
# /Users/jameslarsen/Desktop/LBL/qsppack/qsppack/utils.py:282: ComplexWarning: Casting complex values to real discards the imaginary part
#   fx[ind_union] = opts['fscale'] * func(xpts[ind_union])
# norm error = 9.855641858180775e-10
# max of solution = 0.9999999996799283
# The residual error is
# 0.0019357299025019037

# %%
plt.plot(xlist, targ(xlist)*opts['fscale'], label='True')
plt.plot(xlist, func_value, label='Polynomial Approximation')
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, np.ones(len(xlist)), "k--", label='Constraint')
plt.plot(xlist, -np.ones(len(xlist)), "k--")
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.ylim([-0.01, 1.01])
plt.xlim([0, 1])
plt.show()

# %% [markdown]
# ## Gibbs State

# %%
beta = 2
targ = lambda x: np.exp(-beta * x)
deg = 151
parity = deg % 2
delta = 0.2

opts = {
    'intervals': [delta, 1],
    'objnorm': np.inf,
    'epsil': 0,
    'npts': 151,
    'isplot': False,
    'fscale': 1,
    'method': 'cvxpy'
}
coef_full = cvx_poly_coef(targ, deg, opts)
coef = coef_full[parity::2]


opts.update({
    'N': 2**9,
    'method': 'NLFT',
    'targetPre': False,
    'typePhi': 'reduced'})
phi_proc, out = solve(coef, parity, opts)
out['typePhi'] = 'full'


xlist = np.linspace(0, 1, 1000)
func = lambda x: chebyshev_to_func(x, coef, parity, True)
targ_value = targ(xlist)
func_value = func(xlist)
QSP_value = get_entry(xlist, np.real(phi_proc), out)
err = np.linalg.norm(QSP_value - func_value, np.inf)
print('The residual error is')
print(err)
# Out:
# norm error = 2.8373949856330682e-09
# max of solution = 0.7220070104179717
# The residual error is
# 1.1851630787873546e-14

# %%
plt.plot(xlist, targ(xlist)*opts['fscale'], label='True')
plt.plot(xlist, func_value, label='Polynomial Approximation')
plt.plot(xlist, QSP_value, label='QSP')
plt.plot(xlist, np.ones(len(xlist)), "k--", label='Constraint')
plt.plot(xlist, -np.ones(len(xlist)), "k--")
plt.xlabel('$x$', fontsize=12)
plt.grid()
plt.legend(loc="best")
plt.ylim([-0.01, 1.01])
plt.xlim([0, 1])
plt.show()
